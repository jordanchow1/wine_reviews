# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
df = pd.read_csv("wine.csv",index_col=0)
df = df.drop(labels=["region_2","taster_name","title"],axis='columns')
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1         variety               winery  year
# 0                 Etna     White Blend              Nicosia  2013
# 1                  NaN  Portuguese Red  Quinta dos Avidagos  2011
# 2    Willamette Valley      Pinot Gris            Rainstorm  2013
# 3  Lake Michigan Shore        Riesling           St. Julian  2013
# 4    Willamette Valley      Pinot Noir         Sweet Cheeks  2012

# %% [markdown]
# ### Text Processing

# %% [markdown]
# Converting words in descriptions into binary numbers.

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(stop_words='english', max_features=500, binary=True)
cv.fit(df.description)
X = cv.fit_transform(df.description)
X = X.toarray()
df = pd.concat([df, pd.DataFrame(X)], axis=1)
df.to_csv("new_df.csv")

# %%
from sklearn import linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
df_model = df.sample(500).dropna()
X = df_model.drop(["price",'description'],axis='columns')
drop_enc = OneHotEncoder(drop='first').fit(X)
X = drop_enc.transform(X).toarray()
X = pd.DataFrame(X)
y = np.array(df_model['price']).reshape(-1,)

# %% [markdown]
# ### Random Forest with K-Fold Cross Validation

# %%
kf = KFold(n_splits=5)
mse = []
program_starts = time.time()
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf= RandomForestRegressor(n_estimators=100,max_features=None,n_jobs=-1)
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    mse.append(mean_squared_error(y_pred,y_test))
    plt.scatter(y_pred, y_test-y_pred ,alpha=0.5)
    plt.ylabel("Residual")
    plt.xlabel("Predicted Y")
    plt.title("Residual Plot for Random Forest", size=15)
now = time.time()
print("Runtime: {0} seconds".format(now - program_starts))
# Out:
# Runtime: 6.2956178188323975 seconds

# %%
print("Mean squared error: ",np.mean(mse))
# Out:
# Mean squared error:  2257.9439425716287

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.hist(y_pred)
ax2.hist(y_test)
ax1.set_xlim(0,120)
ax2.set_xlim(0,120)
ax1.set_ylim(0,20)
ax2.set_ylim(0,20)
ax1.set_ylabel("Frequency")
ax2.set_ylabel("Fequency")
fig.suptitle("Histograms of Actual and Predicted Y")
plt.show()

# %% [markdown]
# ### Linear Regression with K-Fold Cross Validation

# %%
kf = KFold(n_splits=5)
mse = []
program_starts = time.time()
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    regr= linear_model.LinearRegression()
    regr.fit(X_train,y_train)
    y_pred = regr.predict(X_test)
    mse.append(mean_squared_error(y_pred,y_test))
    plt.scatter(y_pred, y_test-y_pred ,alpha=0.5)
    plt.xlim(0,200)
    plt.ylabel("Residual")
    plt.xlabel("Predicted Y")
    plt.title("Residual Plot for Linear Regression", size=15)
now = time.time()
print("Runtime: {0} seconds".format(now - program_starts))
# Out:
# Runtime: 0.19653701782226562 seconds

# %%
print("Mean squared error: ",np.mean(mse))
# Out:
# Mean squared error:  2703.43470188997

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.hist(y_pred)
ax2.hist(y_test)
ax1.set_ylim(0,20)
ax2.set_ylim(0,20)
ax1.set_xlim(0,100)
ax2.set_xlim(0,100)
fig.suptitle("Histograms of Actual and Predicted Y")
ax1.set_ylabel("Frequency")
ax2.set_ylabel("Frequency")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.boxplot(df_model.price)
ax2.hist(df_model.price)
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Polynomial Regression with K-Fold Cross Validation

# %%
kf = KFold(n_splits=5)
mse = []
polynomial_features= PolynomialFeatures(degree=2)
X_poly = polynomial_features.fit_transform(X)
program_starts = time.time()
for train_index, test_index in kf.split(X):
    X_train, X_test = X_poly[train_index], X_poly[test_index]
    y_train, y_test = y[train_index], y[test_index]
    regr= linear_model.LinearRegression()
    regr.fit(X_train,y_train)
    y_pred = regr.predict(X_test)
    mse.append(mean_squared_error(y_pred,y_test))
    plt.scatter(y_pred, y_test-y_pred ,alpha=0.5)
    plt.ylabel("Residual")
    plt.xlabel("Predicted Y")
    plt.title("Residual Plot for Polynomial Regression", size=15)
now = time.time()
print("Runtime: {0} seconds".format(now - program_starts))
# Out:
# Runtime: 146.9104199409485 seconds

# %%
print("Mean squared error: ",np.mean(mse))
# Out:
# Mean squared error:  2181.2551147197723

# %%
fig, (ax1, ax2) = plt.subplots(2,1)
ax1.hist(y_pred)
ax2.hist(y_test)
ax1.set_ylim(0,20)
ax2.set_ylim(0,20)
ax1.set_xlim(0,120)
ax2.set_xlim(0,120)
fig.suptitle("Histograms of Actual and Predicted Y")
ax1.set_ylabel("Frequency")
ax2.set_ylabel("Frequency")
plt.show()
