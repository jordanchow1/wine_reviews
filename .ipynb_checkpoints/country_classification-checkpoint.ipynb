# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.feature_extraction.text import CountVectorizer
import time

# %%
df = pd.read_csv("new_df.csv",index_col=0).dropna()

# %%
df_sub = df.sample(5000)

# %% [markdown]
# ### Data Processing

# %% [markdown]
# #### Converting strings into binary numbers.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %%
X = df_sub.drop(["country"],axis='columns')
drop_enc = OneHotEncoder(drop='first').fit(X)
X = pd.DataFrame(drop_enc.transform(X).toarray())
y = np.array(df_sub['country'])
le = LabelEncoder()
le.fit(y)
y = le.transform(y)
print("Numeric labels:",np.unique(y))
print("Original labels:", np.unique(le.inverse_transform(y)))
# Out:
# Numeric labels: [0 1 2 3 4 5 6]
# Original labels: ['Argentina' 'Australia' 'Canada' 'France' 'Italy' 'Spain' 'US']

# %% [markdown]
# #### Distribution of Labels in Subsample

# %%
plt.bar(height = pd.DataFrame(y)[0].value_counts(), x = le.inverse_transform(pd.DataFrame(y)[0].value_counts().index))
plt.title("Number of Wine Reviews by Country", size=15)
plt.ylabel("Frequency")
plt.xlabel("Country")
plt.show()
print(pd.DataFrame(y)[0].value_counts())
# Out:
# 6    2581
# 4     862
# 3     844
# 5     396
# 0     196
# 1     108
# 2      13
# Name: 0, dtype: int64

# %% [markdown]
# #### Percentages of Each Label in Subsample

# %%
for i in range(0,7):
    print("Percentage of",np.unique(le.inverse_transform(y[y==i])),"labels in subsample:",(len(y[y==i])/len(y)*100))
# Out:
# Percentage of ['Argentina'] labels in subsample: 3.92
# Percentage of ['Australia'] labels in subsample: 2.16
# Percentage of ['Canada'] labels in subsample: 0.26
# Percentage of ['France'] labels in subsample: 16.88
# Percentage of ['Italy'] labels in subsample: 17.24
# Percentage of ['Spain'] labels in subsample: 7.920000000000001
# Percentage of ['US'] labels in subsample: 51.62

# %% [markdown]
# ### Classification

# %% [markdown]
# #### Random Forest with K-Fold Cross Validation

# %%
kf = StratifiedKFold(n_splits=3)
f1_scores = []
cm = np.zeros((7,7))
program_starts = time.time()

for train_index, test_index in kf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf= RandomForestClassifier(n_estimators=64,max_features=None)
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    f1_scores.append(f1_score(y_pred,y_test,average='micro'))
    cm += confusion_matrix(y_pred,y_test)
now = time.time()
print("Runtime: {0} seconds".format(now - program_starts))
# Out:
# Runtime: 263.9711980819702 seconds

# %%
sn.heatmap(cm/3,annot=True)
plt.title("Confusion Matrix for Random Forest Classifier")
plt.xlabel('Predicted labels');plt.ylabel('True labels'); 
plt.show()

# %%
print("F1 score:",np.mean(f1_scores))
# Out:
# F1 score: 0.9756001980876334

# %% [markdown]
# ### Logistic Regression with K-Fold Cross Validation

# %%
kf = StratifiedKFold(n_splits=3)
f1_scores = []
cm = np.zeros((7,7))
program_starts = time.time()

for train_index, test_index in kf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf= LogisticRegression()
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    f1_scores.append(f1_score(y_pred,y_test,average='micro'))
    cm += confusion_matrix(y_pred,y_test)
now = time.time()
print("Runtime: {0} seconds".format(now - program_starts))
# Out:
# Runtime: 32.56166911125183 seconds

# %%
sn.heatmap(cm/3,annot=True)
plt.title("Confusion Matrix for Logistic Regressor")
plt.xlabel('Predicted labels');plt.ylabel('True labels'); 
plt.show()

# %%
print("F1 score:",np.mean(f1_scores))
# Out:
# F1 score: 0.9889996790557856

# %% [markdown]
# ### K-Means Classification with K-Fold Cross Validation

# %%
kf = StratifiedKFold(n_splits=3)
f1_scores = []
cm = np.zeros((7,7))
program_starts = time.time()

for train_index, test_index in kf.split(X,y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    clf= KMeans(n_clusters=7)
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    f1_scores.append(f1_score(y_pred,y_test,average='micro'))
    cm += confusion_matrix(y_pred,y_test)
now = time.time()
print("Runtime: {0} seconds".format(now - program_starts))
# Out:
# Runtime: 224.85483407974243 seconds

# %%
sn.heatmap(cm/3,annot=True)
plt.title("Confusion Matrix for K-Means Classifier")
plt.xlabel('Predicted labels');plt.ylabel('True labels'); 
plt.show()

# %%
print("F1 score:",np.mean(f1_scores))
# Out:
# F1 score: 0.14801769538049173
